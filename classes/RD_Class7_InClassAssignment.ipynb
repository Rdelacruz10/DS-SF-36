# %%
import os

import numpy as np

import pandas as pd
pd.set_option('display.max_rows', 50)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 50)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv('storms.csv')

# %%
df
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY  \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0
# 1           1.0   4/18/1950 0:00:00          145       CST     3.0
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0
# 5           1.0  11/15/1951 0:00:00         2000       CST    77.0
# 6           1.0  11/16/1951 0:00:00          100       CST     9.0
# 7           1.0   1/22/1952 0:00:00          900       CST   123.0
# 8           1.0   2/13/1952 0:00:00         2000       CST   125.0
# 9           1.0   2/13/1952 0:00:00         2000       CST    57.0
# 10          1.0   2/13/1952 0:00:00         2030       CST    43.0
# 11          1.0   2/13/1952 0:00:00         2030       CST     9.0
# 12          1.0   2/13/1952 0:00:00         2130       CST    73.0
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    STATE__            BGN_DATE BGN_TIME TIME_ZONE  COUNTY COUNTYNAME STATE  \
# 0      1.0   4/18/1950 0:00:00      130       CST    97.0     MOBILE    AL
# 1      1.0   4/18/1950 0:00:00      145       CST     3.0    BALDWIN    AL
# 2      1.0   2/20/1951 0:00:00     1600       CST    57.0    FAYETTE    AL
# 3      1.0    6/8/1951 0:00:00      900       CST    89.0    MADISON    AL
# 4      1.0  11/15/1951 0:00:00     1500       CST    43.0    CULLMAN    AL
#
#     EVTYPE  BGN_RANGE BGN_AZI BGN_LOCATI END_DATE END_TIME  COUNTY_END  \
# 0  TORNADO        0.0     NaN        NaN      NaN      NaN         0.0
# 1  TORNADO        0.0     NaN        NaN      NaN      NaN         0.0
# 2  TORNADO        0.0     NaN        NaN      NaN      NaN         0.0
# 3  TORNADO        0.0     NaN        NaN      NaN      NaN         0.0
# 4  TORNADO        0.0     NaN        NaN      NaN      NaN         0.0
#
#    COUNTYENDN  END_RANGE END_AZI END_LOCATI  LENGTH  WIDTH    F  MAG  \
# ...

# %%
df.tail()
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY  \
# 902292     56.0  11/30/2011 0:00:00  10:30:00 PM       MST     7.0
# 902293     30.0  11/10/2011 0:00:00  02:48:00 PM       MST     9.0
# 902294      2.0   11/8/2011 0:00:00  02:58:00 PM       AKS   213.0
# 902295      2.0   11/9/2011 0:00:00  10:21:00 AM       AKS   202.0
# 902296      1.0  11/28/2011 0:00:00  08:00:00 PM       CST     6.0
#
#           COUNTYNAME STATE      EVTYPE  BGN_RANGE BGN_AZI BGN_LOCATI  \
# 902292  WYZ007 - 017    WY   HIGH WIND        0.0     NaN        NaN
# 902293  MTZ009 - 010    MT   HIGH WIND        0.0     NaN        NaN
# 902294        AKZ213    AK   HIGH WIND        0.0     NaN        NaN
# 902295        AKZ202    AK    BLIZZARD        0.0     NaN        NaN
# 902296        ALZ006    AL  HEAVY SNOW        0.0     NaN        NaN
#
#                   END_DATE     END_TIME  COUNTY_END  COUNTYENDN  END_RANGE  \
# ...

# %%
df.dtypes
# Out:
# STATE__       float64
# BGN_DATE       object
# BGN_TIME       object
# TIME_ZONE      object
# COUNTY        float64
# COUNTYNAME     object
# STATE          object
# EVTYPE         object
# BGN_RANGE     float64
# BGN_AZI        object
# BGN_LOCATI     object
# END_DATE       object
# END_TIME       object
# COUNTY_END    float64
# COUNTYENDN    float64
# END_RANGE     float64
# END_AZI        object
# END_LOCATI     object
# LENGTH        float64
# WIDTH         float64
# F             float64
# MAG           float64
# FATALITIES    float64
# INJURIES      float64
# PROPDMG       float64
# PROPDMGEXP     object
# CROPDMG       float64
# CROPDMGEXP     object
# WFO            object
# STATEOFFIC     object
# ZONENAMES      object
# LATITUDE      float64
# LONGITUDE     float64
# LATITUDE_E    float64
# LONGITUDE_    float64
# REMARKS        object
# REFNUM        float64
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=902297, step=1)

# %%
df[ ['STATE'] ]
# Out:
#        STATE
# 0         AL
# 1         AL
# 2         AL
# 3         AL
# 4         AL
# 5         AL
# 6         AL
# 7         AL
# 8         AL
# 9         AL
# 10        AL
# 11        AL
# 12        AL
# 13        AL
# 14        AL
# 15        AL
# 16        AL
# 17        AL
# 18        AL
# 19        AL
# 20        AL
# 21        AL
# 22        AL
# 23        AL
# 24        AL
# ...      ...
# 902272    MD
# 902273    VA
# 902274    VA
# 902275    VA
# 902276    VA
# 902277    VA
# 902278    ID
# 902279    AK
# 902280    AK
# 902281    AK
# 902282    AK
# 902283    CO
# 902284    MI
# 902285    WA
# 902286    OK
# 902287    CO
# 902288    TX
# 902289    CO
# 902290    MS
# 902291    TN
# 902292    WY
# 902293    MT
# 902294    AK
# 902295    AK
# 902296    AL
#
# [902297 rows x 1 columns]

# %%
df['STATE']
# Out:
# 0         AL
# 1         AL
# 2         AL
# 3         AL
# 4         AL
# 5         AL
# 6         AL
# 7         AL
# 8         AL
# 9         AL
# 10        AL
# 11        AL
# 12        AL
# 13        AL
# 14        AL
# 15        AL
# 16        AL
# 17        AL
# 18        AL
# 19        AL
# 20        AL
# 21        AL
# 22        AL
# 23        AL
# 24        AL
#           ..
# 902272    MD
# 902273    VA
# 902274    VA
# 902275    VA
# 902276    VA
# 902277    VA
# 902278    ID
# 902279    AK
# 902280    AK
# 902281    AK
# 902282    AK
# 902283    CO
# 902284    MI
# 902285    WA
# 902286    OK
# 902287    CO
# 902288    TX
# 902289    CO
# 902290    MS
# 902291    TN
# 902292    WY
# 902293    MT
# 902294    AK
# 902295    AK
# 902296    AL
# Name: STATE, Length: 902297, dtype: object

# %%
df.isnull()
# Out:
#         STATE__  BGN_DATE  BGN_TIME  TIME_ZONE  COUNTY  COUNTYNAME  STATE  \
# 0         False     False     False      False   False       False  False
# 1         False     False     False      False   False       False  False
# 2         False     False     False      False   False       False  False
# 3         False     False     False      False   False       False  False
# 4         False     False     False      False   False       False  False
# 5         False     False     False      False   False       False  False
# 6         False     False     False      False   False       False  False
# 7         False     False     False      False   False       False  False
# 8         False     False     False      False   False       False  False
# 9         False     False     False      False   False       False  False
# 10        False     False     False      False   False       False  False
# 11        False     False     False      False   False       False  False
# ...

# %%
df.isnull().sum()
# Out:
# STATE__            0
# BGN_DATE           0
# BGN_TIME           0
# TIME_ZONE          0
# COUNTY             0
# COUNTYNAME      1589
# STATE              0
# EVTYPE             0
# BGN_RANGE          0
# BGN_AZI       547332
# BGN_LOCATI    287743
# END_DATE      243411
# END_TIME      238978
# COUNTY_END         0
# COUNTYENDN    902297
# END_RANGE          0
# END_AZI       724837
# END_LOCATI    499225
# LENGTH             0
# WIDTH              0
# F             843563
# MAG                0
# FATALITIES         0
# INJURIES           0
# PROPDMG            0
# PROPDMGEXP    465934
# CROPDMG            0
# CROPDMGEXP    618413
# WFO           142069
# STATEOFFIC    248769
# ZONENAMES     594029
# LATITUDE          47
# LONGITUDE          0
# LATITUDE_E        40
# LONGITUDE_         0
# REMARKS       287433
# REFNUM             0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 6645709L

# %%
df.STATE.count()
# Out:
# 902297

# %%
df.describe()
# Out:
#              STATE__         COUNTY      BGN_RANGE  COUNTY_END  COUNTYENDN  \
# count  902297.000000  902297.000000  902297.000000    902297.0         0.0
# mean       31.200958     100.642905       1.483889         0.0         NaN
# std        16.570178     107.276509       5.481574         0.0         NaN
# min         1.000000       0.000000       0.000000         0.0         NaN
# 25%        19.000000      31.000000       0.000000         0.0         NaN
# 50%        30.000000      75.000000       0.000000         0.0         NaN
# 75%        45.000000     131.000000       1.000000         0.0         NaN
# max        95.000000     873.000000    3749.000000         0.0         NaN
#
#            END_RANGE         LENGTH          WIDTH             F  \
# count  902297.000000  902297.000000  902297.000000  58734.000000
# mean        0.986198       0.230130       7.503044      0.914990
# std         3.374106       4.617236      61.571363      1.002292
# ...

# %%
df.STATE.value_counts()
# Out:
# TX    83728
# KS    53440
# OK    46802
# MO    35648
# IA    31069
# NE    30271
# IL    28488
# AR    27102
# NC    25351
# GA    25259
# OH    24922
# MN    23609
# AL    22739
# PA    22226
# MS    22192
# FL    22124
# KY    22092
# SD    21727
# TN    21721
# IN    21506
# VA    21189
# NY    21058
# CO    20473
# WI    19781
# MI    17910
#       ...
# NV     3139
# NH     3022
# PR     3015
# HI     2547
# DE     1913
# AM     1879
# LE     1526
# LM     1347
# RI      839
# LH      654
# DC      437
# VI      338
# GU      306
# LC      274
# LS      262
# AS      257
# PZ       96
# LO       70
# PH       28
# PK       23
# SL        7
# XX        2
# ST        1
# MH        1
# PM        1
# Name: STATE, Length: 72, dtype: int64

# %%
df.FATALITIES.plot(kind = 'box', figsize = (8,8))

# %%
df[ ['FATALITIES', 'INJURIES'] ].boxplot(figsize = (8, 8))

# %%
n = df.shape[0]

for column in df.columns:
    count = df[column].isnull().sum()
    if count > 0:
        print '{:10s} {:6d} {:3.0f}%'.format(column, count, 100. * count / n)
# Out:
# COUNTYNAME   1589   0%
# BGN_AZI    547332  61%
# BGN_LOCATI 287743  32%
# END_DATE   243411  27%
# END_TIME   238978  26%
# COUNTYENDN 902297 100%
# END_AZI    724837  80%
# END_LOCATI 499225  55%
# F          843563  93%
# PROPDMGEXP 465934  52%
# CROPDMGEXP 618413  69%
# WFO        142069  16%
# STATEOFFIC 248769  28%
# ZONENAMES  594029  66%
# LATITUDE       47   0%
# LATITUDE_E     40   0%
# REMARKS    287433  32%

# %%
df.EVTYPE.value_counts()
# Out:
# HAIL                              288661
# TSTM WIND                         219940
# THUNDERSTORM WIND                  82563
# TORNADO                            60652
# FLASH FLOOD                        54277
# FLOOD                              25326
# THUNDERSTORM WINDS                 20843
# HIGH WIND                          20212
# LIGHTNING                          15754
# HEAVY SNOW                         15708
# HEAVY RAIN                         11723
# WINTER STORM                       11433
# WINTER WEATHER                      7026
# FUNNEL CLOUD                        6839
# MARINE TSTM WIND                    6175
# MARINE THUNDERSTORM WIND            5812
# WATERSPOUT                          3796
# STRONG WIND                         3566
# URBAN/SML STREAM FLD                3392
# WILDFIRE                            2761
# BLIZZARD                            2719
# DROUGHT                             2488
# ICE STORM                           2006
# ...

# %%
exp1 = df.EVTYPE.value_counts()

# %%
lstofOnes = exp1[exp1==1].index.values

# %%
len(lstofOnes)
# Out:
# 489

# %%
lstofOnes
# Out:
# array(['BITTER WIND CHILL', 'Thunderstorm Wind', 'THUNDERSTORM WINDS 61',
#        'THUNDERSTORM WINDS 62', 'COASTAL  FLOODING/EROSION',
#        'HEAT WAVE DROUGHT', 'HIGH WINDS 82', 'Summary of June 30',
#        'BLIZZARD/WINTER STORM', 'DAM FAILURE', 'DUST STORM/HIGH WINDS',
#        'THUNDERSTORM WINDS 60', 'EXTREMELY WET', 'ICE STORM/FLASH FLOOD',
#        'HIGH WIND/WIND CHILL/BLIZZARD', 'HIGH WIND AND SEAS',
#        'SMALL STREAM URBAN FLOOD', 'SMALL STREAM', 'COLD AIR TORNADO',
#        'HIGH WINDS/COASTAL FLOOD', 'SNOWSTORM', 'FUNNEL CLOUD.',
#        'HEAVY SNOW/SLEET', 'DRIEST MONTH', 'LIGHTNING DAMAGE',
#        'THUNDERSTORM WIND.', 'LIGHTNING INJURY', 'DRYNESS', 'TSTMW',
#        'FLOODING/HEAVY RAIN', 'THUNDERSTORM DAMAGE TO', 'RECORD WARM',
#        'WARM DRY CONDITIONS', 'Mild and Dry Pattern',
#        'THUNDERESTORM WINDS', 'FLASH FLOOD LANDSLIDES', 'SEVERE COLD',
#        'TSTM WIND 50', 'RECORD HIGH TEMPERATURES',
# ...

# %%
dffinal = df[df.EVTYPE.isin(lstofOnes) == False]

# %%
dffinal.EVTYPE.unique()
# Out:
# array(['TORNADO', 'TSTM WIND', 'HAIL', 'FREEZING RAIN', 'SNOW', 'SNOW/ICE',
#        'WINTER STORM', 'THUNDERSTORM WINDS', 'RECORD COLD',
#        'HURRICANE ERIN', 'HURRICANE OPAL', 'HEAVY RAIN', 'LIGHTNING',
#        'THUNDERSTORM WIND', 'DENSE FOG', 'RIP CURRENT', 'FLASH FLOOD',
#        'FLASH FLOODING', 'HIGH WINDS', 'FUNNEL CLOUD', 'TORNADO F0',
#        'THUNDERSTORM WINDS LIGHTNING', 'THUNDERSTORM WINDS/HAIL', 'HEAT',
#        'WIND', 'LIGHTING', 'HEAVY RAINS', 'FUNNEL', 'WALL CLOUD',
#        'FLOODING', 'THUNDERSTORM WINDS HAIL', 'FLOOD', 'COLD',
#        'THUNDERSTORM', 'WATERSPOUT', 'EXTREME COLD', 'HIGH WIND',
#        'BLIZZARD', 'WIND CHILL', 'HIGH WIND/BLIZZARD', 'RIVER FLOOD',
#        'HEAVY SNOW', 'FREEZE', 'COASTAL FLOOD', 'HIGH WIND AND HIGH TIDES',
#        'HIGH TIDES', 'RECORD HIGH TEMPERATURE', 'RECORD HIGH', 'ICE STORM',
#        'RECORD LOW', 'AVALANCHE', 'MARINE MISHAP', 'HIGH WIND/HEAVY SNOW',
# ...

# %%
vc = df.EVTYPE.value_counts()

# %%
vcl = vc[vc >1].index.tolist()

# %%
df = df[df.EVTYPE.isin(vcl)]

# %%
l = ['PR','DE', 'AM','LE', 'LM', 'LH', 'DC', 'VI', 'GU', 'LC', 'LS', 'AS', 'PZ', 'LO', 'PH', 
     'PK', 'SL', 'XX', 'ST', 'MH', 'PM']

# %%
df = df.STATE.isin(l) == False
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
#           ...
# 902272    True
# 902273    True
# 902274    True
# 902275    True
# 902276    True
# 902277    True
# 902278    True
# 902279    True
# 902280    True
# 902281    True
# 902282    True
# 902283    True
# 902284    True
# 902285    True
# 902286    True
# 902287    True
# 902288    True
# 902289    True
# 902290    True
# 902291    True
# 902292    True
# 902293    True
# 902294    True
# 902295    True
# 902296    True
# Name: STATE, Length: 902297, dtype: bool

# %%
df = df[df.STATE.isin(l) == False]

# %%
df.STATE.value_counts()
# Out:
# TX    83711
# KS    53435
# OK    46745
# MO    35644
# IA    31057
# NE    30263
# IL    28483
# AR    27101
# NC    25331
# GA    25251
# OH    24916
# MN    23600
# AL    22730
# PA    22209
# MS    22187
# FL    22105
# KY    22085
# TN    21719
# SD    21715
# IN    21502
# VA    21180
# NY    21051
# CO    20457
# WI    19777
# MI    17905
#       ...
# SC    17108
# MT    14686
# ND    14628
# CA    10750
# WV     9079
# MD     8178
# NJ     8065
# WY     7331
# NM     7124
# AZ     6153
# MA     5647
# GM     5337
# OR     4812
# ID     4759
# ME     4515
# AK     4364
# UT     4133
# VT     3866
# WA     3309
# CT     3293
# AN     3250
# NV     3134
# NH     3015
# HI     2542
# RI      838
# Name: STATE, Length: 51, dtype: int64

# %%
df[ ['FATALITIES', 'INJURIES'] ].hist(figsize = (8, 4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x13f9e6910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1113146d0>]], dtype=object)

# %%
df.plot(kind = 'scatter', x = 'LATITUDE', y = 'LONGITUDE', s = 100, figsize = (8, 8))
